# %% [markdown]
# Задание 1. Даны 2 строки: long_phrase и short_phrase. Напишите код, который проверяет действительно ли длинная фраза long_phrase длиннее короткой short_phrase. И выводит True или False в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
long_phrase = 'Вкус французских булок прекрасен' #другой тестовый пример с другими строками
short_phrase = 'Ах упоительны в России вечера, в закатном блеске пламенеет снова лето'

# %%
if len(long_phrase) > len(short_phrase): #сравниваем длины строк с помощью функции len - вычисляет количество символов строки
    print('True')
else:
    print('False')
# Out:
# False

# %% [markdown]
# Задание 2. Дано значение объема файла в байтах (в мегабайте 2^20 байт). Напишите перевод этого значения в мегабайты в формате: "Объем файла равен 213.68Mb".

# %%
V = 15745098732 # вводим объем в байтах,любое целое число

# %%
print('Объем файла равен',"%.2f" % (V/(2**20)),'Mb') #считаем сразу в выводе, ограничиваем количество знаков после запятой
# Out:
# Объем файла равен 15015.70 Mb

# %% [markdown]
# Задание 3. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод: Рыбы

# %%
month = input('Введите месяц:  ')
number = int(input('Введите число:  '))
if (month=='февраль' and number >= 29):  #проверяем чтобы в феврале такая дата существовала, тк короткий месяц
    print('Такой даты не существует, введите правильно месяц и число')
elif (month=='январь' and number <= 20) or (month=='декабрь' and (23 <= number <= 31)):
    print('Вывод: Козерог')
elif (month=='февраль' and number <= 19) or (month=='январь' and (21 <= number <= 31)):
    print('Вывод: Водолей')
elif (month=='март' and number <= 20) or (month=='февраль' and 20 <= number <= 28):
    print('Вывод: Рыбы')
elif (month=='апрель' and number <= 20) or (month=='март' and 21 <= number <= 31):
    print('Вывод: Овен')
elif (month=='май' and number <= 21) or (month=='апрель' and (21 <= number <= 30)):
    print('Вывод: Телец')
elif (month=='июнь' and number <= 21) or (month=='май' and 22 <= number <= 31):
    print('Вывод: Близнецы')
elif (month=='июль' and number <= 22) or (month=='июнь' and 22 <= number <= 30):
    print('Вывод: Рак')
elif (month=='август' and number <= 23) or (month=='июль' and 23 <= number <= 31):
    print('Вывод: Лев')
elif (month=='сентябрь' and number <= 23) or (month=='август' and 24 <= number <= 31):
    print('Вывод: Дева')
elif (month=='октябрь' and number <= 23) or(month=='сентябрь' and 24 <= number <= 30):
    print('Вывод: Весы')
elif (month=='ноябрь' and number <= 22) or (month=='октябрь' and 24 <= number <= 31):
    print('Вывод: Скорпион')
elif (month=='декабрь' and number <= 22) or (month=='ноябрь' and 23 <= number <= 30):
    print('Вывод: Стрелец')
else:
    print('Введите дату правильно')  #все прочие случае будут считаться неправильно введенными датами,
                                    #или несуществующими датами, например 35 июня

# %% [markdown]
# Задание 4. Нужно разработать приложение для финансового планирования. Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию. Пользователь вводит:
#
# заработанную плату в месяц.
# сколько процентов от ЗП уходит на ипотеку.
# сколько процентов от ЗП уходит "на жизнь".
# сколько раз приходит премия в год.
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод: На ипотеку было потрачено: 360000 рублей Было накоплено: 340000 рублей

# %%
money = float(input('Введите заработанную плату в месяц:  '))                    #считываем зарплату в месяц, сразу
                                                                                 #преобразовывая строку в действительное число
salary = 12 * money                                                              # считаем зп за год
percent_ipo = float(input('Введите сколько процентов уходит на ипотеку:  '))     # считываем процент по ипотеке
summa_ipo = percent_ipo * salary / 100                                           # считаем в рублях годовую сумму по ипотеке
percent_life = float(input('Введите сколько процентов уходит на жизнь:  '))      # считываем процент на жизнь
summa_life = percent_life * salary / 100                                         # считаем годовую сумму в рублях
count_bonus = int(input('Введите количество премий за год:  '))                  # считываем количество премий
total = salary - summa_ipo - summa_life + 0.5 * money * count_bonus             # считаем итого накопления на пенсию
print('На ипотеку было потрачено: ',summa_ipo ,'рублей. Было накоплено: ',total,'рублей.')   #выводится ответ
# Out:
# Введите заработанную плату в месяц:  10000
# Введите сколько процентов уходит на ипотеку:  30
# Введите сколько процентов уходит на жизнь:  50
# Введите количество премий за год:  2
# На ипотеку было потрачено:  36000.0 рублей. Было накоплено:  34000.0 рублей.
